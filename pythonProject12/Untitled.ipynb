# %%
import seaborn as sn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
sn.set(rc={'figure.figsize':(15,10)})
_label_encoder = LabelEncoder()
_min_max_scaler = MinMaxScaler()
import scipy.stats as stats

# %% [markdown]
# Wczytujemy Zbiór uzyskany z testów.

# %%
data = pd.read_csv('./experiments_summary.csv')

# %%
data = data.fillna(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   knowledge_base       992 non-null    object
#  1   Linkage_method       992 non-null    object
#  2   Smalest_group_count  992 non-null    int64
#  3   Rule_count           992 non-null    int64
#  4   Computation_time     992 non-null    float64
#  5   Atribute_count       992 non-null    int64
#  6   Distance_messure     992 non-null    object
#  7   Largest_group_count  992 non-null    int64
#  8   Cluster_count        992 non-null    int64
#  9   silhouette_score     992 non-null    float64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 77.6+ KB

# %%
data.columns
# Out:
# Index(['knowledge_base', 'Linkage_method', 'Smalest_group_count', 'Rule_count',
#        'Computation_time', 'Atribute_count', 'Distance_messure',
#        'Largest_group_count', 'Cluster_count', 'silhouette_score'],
#       dtype='object')

# %%
data.groupby(['Distance_messure']).describe()['silhouette_score']
# Out:
#                   count      mean       std       min       25%       50%  \
# Distance_messure
# canberra          248.0  0.415241  0.189852  0.125060  0.257409  0.355118
# chebyshev         248.0  0.173799  0.163080  0.000000  0.000000  0.206552
# cityblock         248.0  0.312019  0.102876  0.000000  0.243859  0.318789
# euclidean         248.0  0.206582  0.098510 -0.196381  0.160523  0.223687
#
#                        75%       max
# Distance_messure
# canberra          0.566390  0.829198
# chebyshev         0.308378  0.470588
# cityblock         0.396434  0.495769
# euclidean         0.278917  0.329026

# %%
grouped_data = data[['Distance_messure', 'silhouette_score']]

# %%
grouped_data.groupby(['Distance_messure']).describe()['silhouette_score'].round(5).to_csv('1.csv')

# %%
grouped_data = grouped_data.fillna(0)

# %%
sn.boxplot(x='Distance_messure', y='silhouette_score', data=grouped_data)
# Out:
# <AxesSubplot:xlabel='Distance_messure', ylabel='silhouette_score'>

# %%
data.groupby(['Linkage_method']).describe()['silhouette_score'].round(5).to_csv('2.csv')

# %%
grouped_linkage_data = data[['Linkage_method', 'silhouette_score']]

# %%
grouped_linkage_data = grouped_linkage_data.fillna(0)

# %%
sn.boxplot(x='Linkage_method', y='silhouette_score', data=grouped_linkage_data)
# Out:
# <AxesSubplot:xlabel='Linkage_method', ylabel='silhouette_score'>

# %%
data.groupby(['Distance_messure']).describe()['Largest_group_count'].round(5).to_csv('3.csv')

# %%
geouped_distance_l_group = data[['Distance_messure', 'Largest_group_count']]

# %%
sn.boxplot(x='Distance_messure', y='Largest_group_count', data=geouped_distance_l_group)
# Out:
# <AxesSubplot:xlabel='Distance_messure', ylabel='Largest_group_count'>

# %%
data.groupby(['Linkage_method']).describe()['Largest_group_count'].round(5).to_csv('4.csv')

# %%
geouped_linkage_l_group = data[['Linkage_method', 'Largest_group_count']]

# %%
sn.boxplot(x='Linkage_method', y='Largest_group_count', data=geouped_linkage_l_group)
# Out:
# <AxesSubplot:xlabel='Linkage_method', ylabel='Largest_group_count'>

# %%
data.groupby(['Distance_messure']).describe()['Smalest_group_count'].round(5).to_csv('5.csv')

# %%
geouped_distance_s_group = data[['Distance_messure', 'Smalest_group_count']]

# %%
sn.boxplot(x='Distance_messure', y='Smalest_group_count', data=geouped_distance_s_group)
# Out:
# <AxesSubplot:xlabel='Distance_messure', ylabel='Smalest_group_count'>

# %%
data.groupby(['Linkage_method']).describe()['Smalest_group_count'].round(5).to_csv('6.csv')

# %%
geouped_linkage_s_group = data[['Linkage_method', 'Smalest_group_count']]

# %%
sn.boxplot(x='Linkage_method', y='Smalest_group_count', data=geouped_linkage_s_group)
plt.savefig('a.png')

# %%
data.groupby(['Distance_messure']).describe()['Computation_time'].round(5).to_csv('7.csv')

# %%
geouped_distance_c_group = data[['Distance_messure', 'Computation_time']]

# %%
sn.boxplot(x='Distance_messure', y='Computation_time', data=geouped_distance_c_group)
plt.savefig('7.png')

# %%
data.groupby(['Linkage_method']).describe()['Computation_time'].round(5).to_csv('8.csv')

# %%
geouped_linkage_c_group = data[['Linkage_method', 'Computation_time']]

# %%
sn.boxplot(x='Linkage_method', y='Computation_time', data=geouped_linkage_c_group)
plt.savefig('8.png')
